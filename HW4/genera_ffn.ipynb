# %% [markdown]
# ### General Feed Forward Network

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import random

# %%
labels = []
numbers = []

with open(os.path.join(os.getcwd(), 'data/MNISTnumLabels5000_balanced.txt'), 'r+') as f:
    lines = f.readlines()
    for line in lines:
        labels.append(int(line))

with open(os.path.join(os.getcwd(), 'data/MNISTnumImages5000_balanced.txt'), 'r+') as f:
    lines = f.readlines()
    for line in lines:
        ind_line = line.split('\t')
        ind_line = [float(i) for i in ind_line]

        numbers.append(ind_line)
    

labels = np.array(labels)
numbers = np.array(numbers)

# %%
index = random.randint(0, 4999)

example_number = numbers[index]
example_label = labels[index]
matrix = example_number.reshape(28, 28).T

print(example_label)
plt.imshow(matrix)
plt.axis('off')
plt.show()
# Out:
# 3

# %%
train_set = []
train_labels = []

test_set = []
test_labels = []

digits = {d: 0 for d in range(0, 10)}

for i in range(len(numbers)):
    label = labels[i]  # get the digit for this image
    
    if label in digits and digits[label] < 400:
        train_set.append(numbers[i])
        train_labels.append(label)
        digits[label] += 1
    else:
        test_set.append(numbers[i])
        test_labels.append(label)
        digits[label] += 1


train_set = np.array(train_set)
test_set = np.array(test_set)
train_labels = np.array(train_labels)
test_labels = np.array(test_labels)
# normalizing the datasets
train_set = train_set.astype(np.float32)/255.0
test_set = test_set.astype(np.float32)/255.0

combined_train_data = list(zip(train_labels, train_set))
random.shuffle(combined_train_data)

combined_test_data = list(zip(test_labels, test_set))
random.shuffle(combined_test_data)

print(len(combined_train_data), len(combined_test_data))
# Out:
# 4000 1000

# %%
m, n = train_set.shape

X_train, X_test = train_set, test_set
Y_train, Y_test = train_labels, test_labels

_, m_train = X_train.shape
_, m_test = X_test.shape

# %%
# Shuffle training set
perm_train = np.random.permutation(X_train.shape[0])  # columns = samples
X_train = X_train[perm_train]
Y_train = np.array(Y_train)[perm_train]  

# Shuffle test set
perm_test = np.random.permutation(X_test.shape[0])
X_test = X_test[perm_test]
Y_test = np.array(Y_test)[perm_test]

X_train.shape, Y_train.shape
# Out:
# ((4000, 784), (4000,))

# %% [markdown]
# ### Neural Network Implementation

# %%
class CustomNeuralNet:

    def __init__(self, layers, layer_sizes, momentum=0.9):
        self.layers = layers
        self.layer_sizes = layer_sizes
        self.momentum = momentum

        self.W = []
        self.b = []
        self.vW = []
        self.vb = []

        self.train_accuracy_over_epochs = []
        self.test_accuracy_over_epochs = []

        for i in range(self.layers - 1):
            in_size = layer_sizes[i]
            out_size = layer_sizes[i+1]

            W_i = np.random.randn(in_size, out_size) * 0.01
            b_i = np.zeros((1, out_size))

            self.W.append(W_i)
            self.b.append(b_i)

            self.vW.append(np.zeros_like(W_i))
            self.vb.append(np.zeros_like(b_i))

    
    ### Activation Functions
    def tanh(self, x):
        return np.tanh(x)
    
    def tanh_deriv(self, x):
        return 1 - np.tanh(x)**2
    
    ### Forward Pass
    def forward(self, x):
        A = x

        '''
        We store A and Z at every layer so that during backprop we can 
        compute gradients for weights, biases, and previous layers.
        '''
        A_cache = [A]
        Z_cache = []

        for i in range(self.layers - 1):
            Z = A @ self.W[i] + self.b[i]       # linear
            A = self.tanh(Z)                   # activation
            Z_cache.append(Z)
            A_cache.append(A)

        return A, Z_cache, A_cache
    
    ### Back propogation
    def backward(self, Y, Z_cache, A_cache):
        m = Y.size

        # Gradients (derivatives)
        dW = [None] * (self.layers - 1)
        db = [None] * (self.layers - 1)

        # Derivative of MSE wrt output activation
        A_final = A_cache[-1]

        if Y.ndim == 1 or Y.shape[1] == 1:
            Y_onehot = np.zeros_like(A_cache[-1])
            Y_onehot[np.arange(len(Y)), Y] = 1
            Y = Y_onehot

        dA = (A_final - Y) * (self.tanh_deriv(Z_cache[-1]))

        # Backprop layer by layer
        for i in reversed(range(self.layers - 1)):
            A_prev = A_cache[i]

            dW[i] = (A_prev.T @ dA) / m
            db[i] = np.sum(dA, axis=0, keepdims=True) / m

            if i > 0:
                dA = (dA @ self.W[i].T) * self.tanh_deriv(Z_cache[i-1])

        return dW, db
    
    ### Momentum Update
    def update_params(self, dW, db, lr):
        for i in range(self.layers - 1):

            # update momentum buffers
            self.vW[i] = self.momentum * self.vW[i] - lr * dW[i]
            self.vb[i] = self.momentum * self.vb[i] - lr * db[i]

            # update parameters
            self.W[i] += self.vW[i]
            self.b[i] += self.vb[i]

    ### Model Training
    def train(self, X, Y, X_test, Y_test, epochs, lr, batch_size=64):
        n = X.shape[0]   # number of samples

        for epoch in range(epochs):

            perm = np.random.permutation(n)
            X = X[perm]
            Y = Y[perm]

            for i in range(0, n, batch_size):
                X_batch = np.array(X[i:i+batch_size])
                Y_batch = np.array(Y[i:i+batch_size])

                # Forward on this batch only
                A, Z_cache, A_cache = self.forward(X_batch)

                # Backprop on this batch only
                dW, db = self.backward(Y_batch, Z_cache, A_cache)

                # Update
                self.update_params(dW, db, lr)

            if epoch % 10 == 0:
                acc = self.accuracy(X, Y)
                acc2 = self.accuracy(X_test, Y_test)

                self.train_accuracy_over_epochs.append(acc)
                self.test_accuracy_over_epochs.append(acc2)
                print(f"Epoch {epoch} | Accuracy: {acc:.4f}")


    def predict(self, X, show=False):
        A, _, _ = self.forward(X)
        result= np.argmax(A, axis=1)
        if show:
            plt.imshow(X.reshape(28,28).T)
            plt.axis('off')
            plt.show()

        return result

    def accuracy(self, X, Y_onehot):
        predictions = self.predict(X)
        return np.mean(predictions == Y_onehot)

    def plot_accuracy_over_epochs(self):
        epochs = list(range(len(self.train_accuracy_over_epochs)))

        plt.figure(figsize=(8, 5))
        plt.plot(epochs, self.train_accuracy_over_epochs, label="Train Accuracy")
        plt.plot(epochs, self.test_accuracy_over_epochs, label="Test Accuracy")

        plt.title("Accuracy Over Epochs")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")

        plt.grid(True)
        plt.legend()

        plt.tight_layout()
        plt.show()

# %% [markdown]
# ### Applying the nn on the dataset

# %%
nn = CustomNeuralNet(layers=3, layer_sizes=[784, 128, 10])

nn.train(X=X_train, Y=Y_train, X_test=X_test, Y_test=Y_test, epochs=5000, lr=0.01, batch_size=100)
# Out:
# Epoch 0 | Accuracy: 0.1000
# Epoch 10 | Accuracy: 0.1000
# Epoch 20 | Accuracy: 0.1000
# Epoch 30 | Accuracy: 0.1000
# Epoch 40 | Accuracy: 0.1000
# Epoch 50 | Accuracy: 0.1000
# Epoch 60 | Accuracy: 0.1000
# Epoch 70 | Accuracy: 0.1485
# Epoch 80 | Accuracy: 0.1000
# Epoch 90 | Accuracy: 0.1000
# Epoch 100 | Accuracy: 0.1000
# Epoch 110 | Accuracy: 0.1000
# Epoch 120 | Accuracy: 0.1000
# Epoch 130 | Accuracy: 0.1000
# Epoch 140 | Accuracy: 0.1000
# Epoch 150 | Accuracy: 0.1003
# Epoch 160 | Accuracy: 0.1455
# Epoch 170 | Accuracy: 0.1785
# Epoch 180 | Accuracy: 0.1000
# Epoch 190 | Accuracy: 0.1118
# Epoch 200 | Accuracy: 0.1003
# Epoch 210 | Accuracy: 0.1000
# Epoch 220 | Accuracy: 0.2600
# Epoch 230 | Accuracy: 0.1000
# Epoch 240 | Accuracy: 0.1800
# Epoch 250 | Accuracy: 0.1695
# Epoch 260 | Accuracy: 0.1190
# Epoch 270 | Accuracy: 0.2028
# Epoch 280 | Accuracy: 0.3455
# Epoch 290 | Accuracy: 0.1570
# Epoch 300 | Accuracy: 0.2690
# Epoch 310 | Accuracy: 0.2853
# Epoch 320 | Accuracy: 0.4078
# Epoch 330 | Accuracy: 0.1740
# Epoch 340 | Accuracy: 0.3157
# Epoch 350 | Accuracy: 0.3397
# Epoch 360 | Accuracy: 0.2870
# Epoch 370 | Accuracy: 0.3018
# Epoch 380 | Accuracy: 0.2730
# Epoch 390 | Accuracy: 0.3575
# Epoch 400 | Accuracy: 0.3110
# Epoch 410 | Accuracy: 0.3337
# Epoch 420 | Accuracy: 0.3130
# Epoch 430 | Accuracy: 0.3685
# Epoch 440 | Accuracy: 0.3515
# Epoch 450 | Accuracy: 0.4042
# Epoch 460 | Accuracy: 0.3458
# Epoch 470 | Accuracy: 0.4088
# Epoch 480 | Accuracy: 0.3890
# Epoch 490 | Accuracy: 0.3500
# Epoch 500 | Accuracy: 0.3545
# Epoch 510 | Accuracy: 0.3690
# Epoch 520 | Accuracy: 0.3448
# Epoch 530 | Accuracy: 0.3850
# Epoch 540 | Accuracy: 0.3780
# Epoch 550 | Accuracy: 0.3852
# Epoch 560 | Accuracy: 0.4290
# Epoch 570 | Accuracy: 0.4240
# Epoch 580 | Accuracy: 0.3827
# Epoch 590 | Accuracy: 0.4402
# Epoch 600 | Accuracy: 0.4118
# Epoch 610 | Accuracy: 0.4412
# Epoch 620 | Accuracy: 0.4133
# Epoch 630 | Accuracy: 0.4198
# Epoch 640 | Accuracy: 0.4308
# Epoch 650 | Accuracy: 0.4225
# Epoch 660 | Accuracy: 0.4557
# Epoch 670 | Accuracy: 0.4865
# Epoch 680 | Accuracy: 0.5028
# Epoch 690 | Accuracy: 0.4840
# Epoch 700 | Accuracy: 0.5235
# Epoch 710 | Accuracy: 0.4865
# Epoch 720 | Accuracy: 0.5215
# Epoch 730 | Accuracy: 0.5420
# Epoch 740 | Accuracy: 0.5085
# Epoch 750 | Accuracy: 0.5697
# Epoch 760 | Accuracy: 0.5537
# Epoch 770 | Accuracy: 0.5800
# Epoch 780 | Accuracy: 0.5813
# Epoch 790 | Accuracy: 0.5677
# Epoch 800 | Accuracy: 0.5697
# Epoch 810 | Accuracy: 0.6158
# Epoch 820 | Accuracy: 0.6275
# Epoch 2980 | Accuracy: 0.8423
# Epoch 2990 | Accuracy: 0.8530
# Epoch 3000 | Accuracy: 0.8502
# Epoch 3010 | Accuracy: 0.8425
# Epoch 3020 | Accuracy: 0.8498
# Epoch 3030 | Accuracy: 0.8442
# Epoch 3040 | Accuracy: 0.8373
# Epoch 3050 | Accuracy: 0.8397
# Epoch 3060 | Accuracy: 0.8280
# Epoch 3070 | Accuracy: 0.8375
# Epoch 3080 | Accuracy: 0.8387
# Epoch 3090 | Accuracy: 0.8285
# Epoch 3100 | Accuracy: 0.8410
# Epoch 3110 | Accuracy: 0.8413
# Epoch 3120 | Accuracy: 0.8425
# Epoch 3130 | Accuracy: 0.8403
# Epoch 3140 | Accuracy: 0.8455
# Epoch 3150 | Accuracy: 0.8485
# Epoch 3160 | Accuracy: 0.8393
# Epoch 3170 | Accuracy: 0.8425
# Epoch 3180 | Accuracy: 0.8448
# Epoch 3190 | Accuracy: 0.8462
# Epoch 3200 | Accuracy: 0.8478
# Epoch 3210 | Accuracy: 0.8485
# Epoch 3220 | Accuracy: 0.8470
# Epoch 3230 | Accuracy: 0.8393
# Epoch 3240 | Accuracy: 0.8468
# Epoch 3250 | Accuracy: 0.8548
# Epoch 3260 | Accuracy: 0.8518
# Epoch 3270 | Accuracy: 0.8407
# Epoch 3280 | Accuracy: 0.8568
# Epoch 3290 | Accuracy: 0.8377
# Epoch 3300 | Accuracy: 0.8440
# Epoch 3310 | Accuracy: 0.8438
# Epoch 3320 | Accuracy: 0.8492
# Epoch 3330 | Accuracy: 0.8548
# Epoch 3340 | Accuracy: 0.8518
# Epoch 3350 | Accuracy: 0.8512
# Epoch 3360 | Accuracy: 0.8462
# Epoch 3370 | Accuracy: 0.8415
# Epoch 3380 | Accuracy: 0.8492
# Epoch 3390 | Accuracy: 0.8492
# Epoch 3400 | Accuracy: 0.8405
# Epoch 3410 | Accuracy: 0.8433
# Epoch 3420 | Accuracy: 0.8490
# Epoch 3430 | Accuracy: 0.8558
# Epoch 3440 | Accuracy: 0.8460
# Epoch 3450 | Accuracy: 0.8528
# Epoch 3460 | Accuracy: 0.8460
# Epoch 3470 | Accuracy: 0.8462
# Epoch 3480 | Accuracy: 0.8502
# Epoch 3490 | Accuracy: 0.8548
# Epoch 3500 | Accuracy: 0.8478
# Epoch 3510 | Accuracy: 0.8552
# Epoch 3520 | Accuracy: 0.8608
# Epoch 3530 | Accuracy: 0.8403
# Epoch 3540 | Accuracy: 0.8498
# Epoch 3550 | Accuracy: 0.8490
# Epoch 3560 | Accuracy: 0.8515
# Epoch 3570 | Accuracy: 0.8472
# Epoch 3580 | Accuracy: 0.8363
# Epoch 3590 | Accuracy: 0.8470
# Epoch 3600 | Accuracy: 0.8433
# Epoch 3610 | Accuracy: 0.8470
# Epoch 3620 | Accuracy: 0.8530
# Epoch 3630 | Accuracy: 0.8393
# Epoch 3640 | Accuracy: 0.8452
# Epoch 3650 | Accuracy: 0.8562
# Epoch 3660 | Accuracy: 0.8468
# Epoch 3670 | Accuracy: 0.8590
# Epoch 3680 | Accuracy: 0.8552
# Epoch 3690 | Accuracy: 0.8305
# Epoch 3700 | Accuracy: 0.8525
# Epoch 3710 | Accuracy: 0.8595
# Epoch 3720 | Accuracy: 0.8575
# Epoch 3730 | Accuracy: 0.8373
# Epoch 3740 | Accuracy: 0.8442
# Epoch 3750 | Accuracy: 0.8485
# Epoch 3760 | Accuracy: 0.8508
# Epoch 3770 | Accuracy: 0.8552
# Epoch 3780 | Accuracy: 0.8555
# Epoch 3790 | Accuracy: 0.8510
# Epoch 3800 | Accuracy: 0.8605
# Epoch 3810 | Accuracy: 0.8525
# Epoch 3820 | Accuracy: 0.8560
# Epoch 3830 | Accuracy: 0.8612
# Epoch 3840 | Accuracy: 0.8530
# Epoch 3850 | Accuracy: 0.8363
# Epoch 3860 | Accuracy: 0.8512
# Epoch 3870 | Accuracy: 0.8440
# Epoch 3880 | Accuracy: 0.8500
# Epoch 3890 | Accuracy: 0.8472
# Epoch 3900 | Accuracy: 0.8548
# Epoch 3910 | Accuracy: 0.8488
# Epoch 3920 | Accuracy: 0.8305
# Epoch 3930 | Accuracy: 0.8575
# Epoch 3940 | Accuracy: 0.8575
# Epoch 3950 | Accuracy: 0.8502
# Epoch 3960 | Accuracy: 0.8417
# Epoch 3970 | Accuracy: 0.8520
# Epoch 3980 | Accuracy: 0.8535
# Epoch 3990 | Accuracy: 0.8448
# Epoch 4000 | Accuracy: 0.8478
# Epoch 4010 | Accuracy: 0.8440
# Epoch 4020 | Accuracy: 0.8555
# Epoch 4030 | Accuracy: 0.8518
# Epoch 4040 | Accuracy: 0.8455
# Epoch 4050 | Accuracy: 0.8562
# Epoch 4060 | Accuracy: 0.8518
# Epoch 4070 | Accuracy: 0.8542
# Epoch 4080 | Accuracy: 0.8347
# Epoch 4090 | Accuracy: 0.8495
# Epoch 4100 | Accuracy: 0.8442
# Epoch 4110 | Accuracy: 0.8495
# Epoch 4120 | Accuracy: 0.8535
# Epoch 4130 | Accuracy: 0.8542
# Epoch 4140 | Accuracy: 0.8565
# Epoch 4150 | Accuracy: 0.8470
# Epoch 4160 | Accuracy: 0.8333
# Epoch 4170 | Accuracy: 0.8555
# Epoch 4180 | Accuracy: 0.8580
# Epoch 4190 | Accuracy: 0.8588
# Epoch 4200 | Accuracy: 0.8327
# Epoch 4210 | Accuracy: 0.8485
# Epoch 4220 | Accuracy: 0.8475
# Epoch 4230 | Accuracy: 0.8353
# Epoch 4240 | Accuracy: 0.8558
# Epoch 4250 | Accuracy: 0.8500
# Epoch 4260 | Accuracy: 0.8478
# Epoch 4270 | Accuracy: 0.8540
# Epoch 4280 | Accuracy: 0.8580
# Epoch 4290 | Accuracy: 0.8600
# Epoch 4300 | Accuracy: 0.8495
# Epoch 4310 | Accuracy: 0.8592
# Epoch 4320 | Accuracy: 0.8590
# Epoch 4330 | Accuracy: 0.8460
# Epoch 4340 | Accuracy: 0.8562
# Epoch 4350 | Accuracy: 0.8642
# Epoch 4360 | Accuracy: 0.8488
# Epoch 4370 | Accuracy: 0.8572
# Epoch 4380 | Accuracy: 0.8598
# Epoch 4390 | Accuracy: 0.8430
# Epoch 4400 | Accuracy: 0.8615
# Epoch 4410 | Accuracy: 0.8622
# Epoch 4420 | Accuracy: 0.8532
# Epoch 4430 | Accuracy: 0.8580
# Epoch 4440 | Accuracy: 0.8570
# Epoch 4450 | Accuracy: 0.8347
# Epoch 4460 | Accuracy: 0.8420
# Epoch 4470 | Accuracy: 0.8530
# Epoch 4480 | Accuracy: 0.8535
# Epoch 4490 | Accuracy: 0.8585
# Epoch 4500 | Accuracy: 0.8515
# Epoch 4510 | Accuracy: 0.8595
# Epoch 4520 | Accuracy: 0.8550
# Epoch 4530 | Accuracy: 0.8550
# Epoch 4540 | Accuracy: 0.8600
# Epoch 4550 | Accuracy: 0.8528
# Epoch 4560 | Accuracy: 0.8410
# Epoch 4570 | Accuracy: 0.8538
# Epoch 4580 | Accuracy: 0.8578
# Epoch 4590 | Accuracy: 0.8490
# Epoch 4600 | Accuracy: 0.8572
# Epoch 4610 | Accuracy: 0.8505
# Epoch 4620 | Accuracy: 0.8535
# Epoch 4630 | Accuracy: 0.8598
# Epoch 4640 | Accuracy: 0.8492
# Epoch 4650 | Accuracy: 0.8485
# Epoch 4660 | Accuracy: 0.8482
# Epoch 4670 | Accuracy: 0.8450
# Epoch 4680 | Accuracy: 0.8470
# Epoch 4690 | Accuracy: 0.8430
# Epoch 4700 | Accuracy: 0.8602
# Epoch 4710 | Accuracy: 0.8542
# Epoch 4720 | Accuracy: 0.8500
# Epoch 4730 | Accuracy: 0.8605
# Epoch 4740 | Accuracy: 0.8555
# Epoch 4750 | Accuracy: 0.8630
# Epoch 4760 | Accuracy: 0.8580
# Epoch 4770 | Accuracy: 0.8635
# Epoch 4780 | Accuracy: 0.8572
# Epoch 4790 | Accuracy: 0.8495
# Epoch 4800 | Accuracy: 0.8538
# Epoch 4810 | Accuracy: 0.8590
# Epoch 4820 | Accuracy: 0.8578
# Epoch 4830 | Accuracy: 0.8542
# Epoch 4840 | Accuracy: 0.8600
# Epoch 4850 | Accuracy: 0.8620
# Epoch 4860 | Accuracy: 0.8552
# Epoch 4870 | Accuracy: 0.8595
# Epoch 4880 | Accuracy: 0.8545
# Epoch 4890 | Accuracy: 0.8555
# Epoch 4900 | Accuracy: 0.8377
# Epoch 4910 | Accuracy: 0.8535
# Epoch 4920 | Accuracy: 0.8632
# Epoch 4930 | Accuracy: 0.8605
# Epoch 4940 | Accuracy: 0.8490
# Epoch 4950 | Accuracy: 0.8568
# Epoch 4960 | Accuracy: 0.8530
# Epoch 4970 | Accuracy: 0.8433
# Epoch 4980 | Accuracy: 0.8522
# Epoch 4990 | Accuracy: 0.8532

# %%
nn.accuracy(X_test, Y_test)
# Out:
# 0.854

# %%
nn.plot_accuracy_over_epochs()

# %%
nn.accuracy(X_train, Y_train)
# Out:
# 0.8625

# %%
index = random.randint(0, 999)
A = nn.predict(X_test[index], show=True)
A[0]
# Out:
# 9

# %%
np.savez("model_weights.npz", W1=nn.W[0], b1=nn.b[0], W2=nn.W[1], b2=nn.b[1])

# %%
data = np.load("model_weights.npz")
W1_copy = data["W1"]
b1_copy = data["b1"]
W2_copy = data["W2"]
b2_copy = data["b2"]

nn.W[0] == W1_copy
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])
