# %%
from dotenv import load_dotenv
import os
import openai
import pandas as pd
import csv

# %%
load_dotenv()
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\User\\projects\\Intelligent_Systems\\HW1'

# %%
model = openai.OpenAI(api_key=OPENAI_API_KEY)

def get_response(prompt):
    response = model.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "List the first five words that come to your mind when you hear the word X. Only give me the five words, and nothing else."},
            {"role":"user", "content": prompt}
        ]
    )

    return response.choices[0].message.content

# Part 1
def store_responses_part1(cue, response):
    file_path = r'C:\Users\User\projects\Intelligent_Systems\HW1\GPT_Responses\GPT_responses1.csv'

    with open(file_path, mode="a", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow([cue, response])

# %% [markdown]
# #### PART 1

# %%
# My cues are below
cues = {
    "car": "Drive, Park, Drift, Buy, Sell",
    "plant": "Water, Tea, Aloe Vera, Mint, Green",
    "warm": "Summer, Sun, Love, Wholesome, Sweater",
    "heavy": "Bag, Weights, Kilograms, Pounds, Emotions",
    "read": "Book, Emotions, Red, Minds, Stories",
    "coffee": "Energy, Tasty, Yummy, All-nighter, Heart-attack",
    "yogurt": "Protein, Milk, Fermented, Sour, Spoon"
}

raw_ques = list(cues.keys())

for cue in raw_ques:
    prompt = f"List the first five words that come to your mind when you hear the word {cue}. Only give me the five words, and nothing else. No full stops either."
    for i in range(0, 10):
        response = get_response(prompt)
        store_responses_part1(cue, response)

print("Done")
# Out:
# Done

# %%
file_path = r'C:\Users\User\projects\Intelligent_Systems\HW1\GPT_Responses\GPT_responses1.csv'

with open(file_path, mode='r', encoding="utf-8") as f:
    reader = csv.reader(f)
    responses = []
    for row in reader:
        if row[0] == 'yogurt':
            split = row[1].split(' ')
            for i in split:
                responses.append(i.lower().strip())

        # responses = []
    

    prob = {}
    for i in responses:
        if i in prob.keys() or (i + '.') in prob.keys():
            prob[i] += 1
        else:
            prob[i] = 1
    
    print(prob)
# Out:
# {'dairy': 4, 'probiotic': 10, 'creamy': 10, 'tangy': 5, 'healthy': 8, 'snack': 8, 'dessert': 1, 'flavor': 1, 'tart': 2, 'delicious': 3}

# %%
master_dict = {'car': {
    'engine': 7, 
    'wheels': 3, 
    'speed': 10, 
    'transport': 5, 
    'drive': 6, 
    'vehicle': 4, 
    'road': 4, 
    'travel': 6, 
    'freedom': 2, 
    'safety': 1, 
    'transportation': 1, 
    'driving': 1
},

'plant': {
    'green': 10, 
    'photosynthesis': 7, 
    'growth': 10, 
    'soil': 8, 
    'flowers': 1, 
    'leaves': 1, 
    'nature': 7, 
    'oxygen': 3, 
    'life': 1, 
    'nurture': 1, 
    'garden': 1
},

# Warm
'warm' : {
    'cozy': 10, 
    'sunny': 2, 
    'comfort': 8, 
    'heat': 9, 
    'pleasant': 1, 
    'sunlight': 5, 
    'friendly': 2, 
    'embrace': 2, 
    'comforting': 1, 
    'sunshine': 2, 
    'relaxation': 1, 
    'comfortable': 1, 
    'toasty': 1, 
    'fire': 1, 
    'soft': 1, 
    'happiness': 1, 
    'enjoyable': 1, 
    'summer': 1
},

# Heavy
'heavy' : {
    'weight': 8, 
    'burden': 5, 
    'dense': 10, 
    'solid': 4, 
    'strong': 2, 
    'substantial': 3, 
    'load': 6, 
    'burdensome': 5, 
    'significant': 2, 
    'weighty': 2, 
    'massive': 1, 
    'forceful': 1, 
    'pressure': 1
},

# Read
'read' : {
    'books': 9, 
    'knowledge': 10, 
    'understanding': 4,
    'imagination': 10, 
    'escape': 7, 
    'learning': 7, 
    'comprehension': 1, 
    'book': 1, 
    'words': 1
},

# Coffee
'coffee' : {
    'caffeine': 10, 
    'aroma': 10, 
    'morning': 6, 
    'energy': 8,
    'comfort': 3, 
    'warmth': 6, 
    'brew': 4, 
    'beans': 1, 
    'espresso': 1, 
    'mug': 1
},

# Yogurt
'yogurt': {
    'dairy': 4, 
    'probiotic': 10, 
    'creamy': 10, 
    'tangy': 5, 
    'healthy': 8, 
    'snack': 8, 
    'dessert': 1, 
    'flavor': 1, 
    'tart': 2, 
    'delicious': 3
}}

# %%
print(raw_ques)
# Out:
# ['car', 'plant', 'warm', 'heavy', 'read', 'coffee', 'yogurt']

# %%
probabilities_dict = {}
for cue in raw_ques:
    probabilities_dict[cue] = {}
    for key, value in master_dict[cue].items():
        probabilities_dict[cue][key] = value/50
    

probabilities_dict_sorted = {}
# Sorting in descending order
for cue, subdict in probabilities_dict.items():
    sorted_items = sorted(subdict.items(), key=lambda x: x[1], reverse=True)

    probabilities_dict_sorted[cue] = dict(sorted_items)

print(probabilities_dict_sorted)
# Out:
# {'car': {'speed': 0.2, 'engine': 0.14, 'drive': 0.12, 'travel': 0.12, 'transport': 0.1, 'vehicle': 0.08, 'road': 0.08, 'wheels': 0.06, 'freedom': 0.04, 'safety': 0.02, 'transportation': 0.02, 'driving': 0.02}, 'plant': {'green': 0.2, 'growth': 0.2, 'soil': 0.16, 'photosynthesis': 0.14, 'nature': 0.14, 'oxygen': 0.06, 'flowers': 0.02, 'leaves': 0.02, 'life': 0.02, 'nurture': 0.02, 'garden': 0.02}, 'warm': {'cozy': 0.2, 'heat': 0.18, 'comfort': 0.16, 'sunlight': 0.1, 'sunny': 0.04, 'friendly': 0.04, 'embrace': 0.04, 'sunshine': 0.04, 'pleasant': 0.02, 'comforting': 0.02, 'relaxation': 0.02, 'comfortable': 0.02, 'toasty': 0.02, 'fire': 0.02, 'soft': 0.02, 'happiness': 0.02, 'enjoyable': 0.02, 'summer': 0.02}, 'heavy': {'dense': 0.2, 'weight': 0.16, 'load': 0.12, 'burden': 0.1, 'burdensome': 0.1, 'solid': 0.08, 'substantial': 0.06, 'strong': 0.04, 'significant': 0.04, 'weighty': 0.04, 'massive': 0.02, 'forceful': 0.02, 'pressure': 0.02}, 'read': {'knowledge': 0.2, 'imagination': 0.2, 'books': 0.18, 'escape': 0.14, 'learning': 0.14, 'understanding': 0.08, 'comprehension': 0.02, 'book': 0.02, 'words': 0.02}, 'coffee': {'caffeine': 0.2, 'aroma': 0.2, 'energy': 0.16, 'morning': 0.12, 'warmth': 0.12, 'brew': 0.08, 'comfort': 0.06, 'beans': 0.02, 'espresso': 0.02, 'mug': 0.02}, 'yogurt': {'probiotic': 0.2, 'creamy': 0.2, 'healthy': 0.16, 'snack': 0.16, 'tangy': 0.1, 'dairy': 0.08, 'delicious': 0.06, 'tart': 0.04, 'dessert': 0.02, 'flavor': 0.02}}

# %%
# Probabilities
probabilities_dict_sorted = {
   "car":{
      "speed":0.2,
      "engine":0.14,
      "drive":0.12,
      "travel":0.12,
      "transport":0.1,
      "vehicle":0.08,
      "road":0.08,
      "wheels":0.06,
      "freedom":0.04,
      "safety":0.02,
      "transportation":0.02,
      "driving":0.02
   },
   "plant":{
      "green":0.2,
      "growth":0.2,
      "soil":0.16,
      "photosynthesis":0.14,
      "nature":0.14,
      "oxygen":0.06,
      "flowers":0.02,
      "leaves":0.02,
      "life":0.02,
      "nurture":0.02,
      "garden":0.02
   },
   "warm":{
      "cozy":0.2,
      "heat":0.18,
      "comfort":0.16,
      "sunlight":0.1,
      "sunny":0.04,
      "friendly":0.04,
      "embrace":0.04,
      "sunshine":0.04,
      "pleasant":0.02,
      "comforting":0.02,
      "relaxation":0.02,
      "comfortable":0.02,
      "toasty":0.02,
      "fire":0.02,
      "soft":0.02,
      "happiness":0.02,
      "enjoyable":0.02,
      "summer":0.02
   },
   "heavy":{
      "dense":0.2,
      "weight":0.16,
      "load":0.12,
      "burden":0.1,
      "burdensome":0.1,
      "solid":0.08,
      "substantial":0.06,
      "strong":0.04,
      "significant":0.04,
      "weighty":0.04,
      "massive":0.02,
      "forceful":0.02,
      "pressure":0.02
   },
   "read":{
      "knowledge":0.2,
      "imagination":0.2,
      "books":0.18,
      "escape":0.14,
      "learning":0.14,
      "understanding":0.08,
      "comprehension":0.02,
      "book":0.02,
      "words":0.02
   },
   "coffee":{
      "caffeine":0.2,
      "aroma":0.2,
      "energy":0.16,
      "morning":0.12,
      "warmth":0.12,
      "brew":0.08,
      "comfort":0.06,
      "beans":0.02,
      "espresso":0.02,
      "mug":0.02
   },
   "yogurt":{
      "probiotic":0.2,
      "creamy":0.2,
      "healthy":0.16,
      "snack":0.16,
      "tangy":0.1,
      "dairy":0.08,
      "delicious":0.06,
      "tart":0.04,
      "dessert":0.02,
      "flavor":0.02
   }
}

# %%
# Incidence matching
# (Number of matched responses by 5)

cues = {
    "car": "Drive, Park, Drift, Buy, Sell",
    "plant": "Water, Tea, Aloe Vera, Mint, Green",
    "warm": "Summer, Sun, Love, Wholesome, Sweater",
    "heavy": "Bag, Weight, Kilograms, Pounds, Emotions",
    "read": "Book, Emotions, Red, Minds, Stories",
    "coffee": "Energy, Tasty, Yummy, All-nighter, Heart-attack",
    "yogurt": "Protein, Milk, Fermented, Sour, Spoon"
}

for key, value in cues.items():
    split_vals = value.split(',')
    for i in range(len(split_vals)):
        split_vals[i] = split_vals[i].strip().lower()
    cues[key] = split_vals

# %%
incidence = {'car': 0, 'plant': 0, 'warm': 0, 'heavy': 0, 'read': 0, 'coffee': 0, 'yogurt': 0}

for key, subdict in probabilities_dict_sorted.items():
    for word in subdict.keys():
        if word in cues[key]:
            incidence[key] += 1


for key, value in incidence.items():
    incidence[key] = value/5

incidence
# For this, should I be literal or should I take semantic matching?
# Out:
# {'car': 0.2,
#  'plant': 0.2,
#  'warm': 0.2,
#  'heavy': 0.2,
#  'read': 0.2,
#  'coffee': 0.2,
#  'yogurt': 0.0}

# %%
x = list(probabilities_dict_sorted['car'].keys())
print(probabilities_dict_sorted['car'])
for index, element in enumerate(x):
    print(element, index + 1)
# Out:
# {'speed': 0.2, 'engine': 0.14, 'drive': 0.12, 'travel': 0.12, 'transport': 0.1, 'vehicle': 0.08, 'road': 0.08, 'wheels': 0.06, 'freedom': 0.04, 'safety': 0.02, 'transportation': 0.02, 'driving': 0.02}
# speed 1
# engine 2
# drive 3
# travel 4
# transport 5
# vehicle 6
# road 7
# wheels 8
# freedom 9
# safety 10
# transportation 11
# driving 12

# %%
# Frequency Match

frequencies = {}

for cue in raw_ques:
    cue_sum = 0
    sorted_responses = list(probabilities_dict_sorted[cue].keys())
    for index, element in enumerate(sorted_responses):
        if element in cues[cue]:
            cue_sum += (index + 1)
        else:
            cue_sum += 51
    
    frequencies[cue] = round(15 / cue_sum, 4)

frequencies
# Out:
# {'car': 0.0266,
#  'plant': 0.0294,
#  'warm': 0.0169,
#  'heavy': 0.0244,
#  'read': 0.0361,
#  'coffee': 0.0325,
#  'yogurt': 0.0294}
